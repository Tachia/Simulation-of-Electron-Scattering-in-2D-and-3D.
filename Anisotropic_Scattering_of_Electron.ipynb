# %% [markdown]
# <a href="https://colab.research.google.com/github/Tachia/Simulation-of-Electron-Scattering-in-2D-and-3D./blob/main/Anisotropic_Scattering_of_Electron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MONTE CARLO SIMULATION
# (3D Simulation)
#
# Point source is anisotropic: all electrons are emitted along one direction; electron-atom scattering is anisotropic: Theta, θ is determined from sin(θ/2) = a_3, (where a_1, a_2 and a_3 are random numbers selected between 0 and 1)
#
# Determination of λ and φ is given by:
# Lambda, λ = -lna_1, phi, φ = 2πa_2.
#
# It is necessary to make simulation for the anisotropic case and to compare results with previous results for isotropic case.
# Lambda is the length between the collisions, phi and theta are the angular displacement in x-y, x-z coordinates respectively.
#
# From the sine identity formula, we have that:
#
# sin(θ/2) = a_3
#
# θ = 2arcsin(a_3)

# %%
#@title
import numpy as np
import matplotlib.pyplot as plt
import random

numbere = 1
num_a = 100
e = []
for j in range(numbere):
  ax = plt.axes(projection="3d")
  a = np.random.uniform(size=num_a)
  b = np.random.uniform(size=num_a)
  c = np.random.uniform(size=num_a)
  a = c
  ex = [0]
  ey = [0]
  ez = [0]
  for i in range(len(a)):
    Lambda = -np.log(a[i])
    phi = 2*np.pi*b[i]
    theta = 2*np.arcsin(c[i])

    X = (Lambda*np.sin(theta)*np.cos(phi)) 
    Y = (Lambda*np.sin(theta)*np.sin(phi)) 
    Z = (Lambda*np.cos(theta)) 

    ex.append(X)
    ey.append(Y)
    ez.append(Z)
  plt.plot(ex, ey, ez, linestyle='-',color ="navy", linewidth = 3, marker='o', markerfacecolor='green', markersize=10)
plt.show()

L = []
lx = 0
ly = 0
lz = 0
N = []
n = 1
for i in range(len(a)):
  N.append(n)
  n = n + 1
  lx = lx + (ex[i])
  ly = ly + (ey[i])
  lz = lz + (ez[i])
  L.append(((lx+ly+lz)**(1/2)))

plt.plot(N, L, color ="darkblue")
plt.title("The Distance from the Source against Number of Collisions: Absolute Values")
plt.xlabel("Number of Collisions")
plt.ylabel("The Distance from the Source")
plt.show()

# %%
#@title
import numpy as np
from scipy import stats
import numpy
import pandas as pd

numpy.seterr(divide = 'ignore')
y = np.log(L)
x = np.log(N)
plt.plot(x,y, c = "navy")
plt.title("The graph of log(L) versus log(N)", fontsize = "20")
plt.xlabel("log(N)", fontsize = "20")
plt.ylabel("log(L)", fontsize = "20")
plt.grid()

print("The min. and max. values of log(L) and log(N):",(min(x), max(x), min(y), max(y)))
print("\n")
p = max(y)
l = (max(x) - min(x))
n = (max(y) - min(y))
m = (p/l)
print("The Slope of log(L) versus log(N):", m)
print("\n")
# Out:
# The min. and max. values of log(L) and log(N): (0.0, 4.605170185988092, -inf, 1.9164629225230747)
#
#
# The Slope of log(L) versus log(N): 0.4161546360119753

# %%
#@title
import numpy as np
import matplotlib.pyplot as plt
import random

numbere = 1
num_a = 100
e = []
for j in range(numbere):
  ax = plt.axes(projection="3d")
  a = np.random.uniform(size=num_a)
  b = np.random.uniform(size=num_a)
  c = np.random.uniform(size=num_a)
  a = c
  ex = [0]
  ey = [0]
  ez = [0]
  for i in range(len(a)):
    Lambda = -np.log(a[i])
    phi = 2*np.pi*b[i]
    theta = 2*np.arcsin(c[i])

    X = (Lambda*np.sin(theta)*np.cos(phi)) 
    Y = (Lambda*np.sin(theta)*np.sin(phi)) 
    Z = (Lambda*np.sin(theta)) 

    ex.append(X)
    ey.append(Y)
    ez.append(Z)
  plt.plot(ex, ey, ez, linestyle='-',color ="navy", linewidth = 3, marker='o', markerfacecolor='green', markersize=10)
plt.show()

L = []
lx = 0
ly = 0
lz = 0
N = []
n = 1
for i in range(len(a)):
  N.append(n)
  n = n + 1
  lx = lx + (ex[i])
  ly = ly + (ey[i])
  lz = lz + (ez[i])
  L.append(((lx+ly+lz)**(1/2)))

plt.plot(N, L, color ="darkblue")
plt.title("The Distance from the Source against Number of Collisions: Absolute Values")
plt.xlabel("Number of Collisions")
plt.ylabel("The Distance from the Source")
plt.show()

# %%
#@title
import numpy as np
from scipy import stats
import numpy
import pandas as pd

numpy.seterr(divide = 'ignore')
y = np.log(L)
x = np.log(N)
plt.plot(x,y, c = "navy")
plt.title("The graph of log(L) versus log(N)", fontsize = "20")
plt.xlabel("log(N)", fontsize = "20")
plt.ylabel("log(L)", fontsize = "20")
plt.grid()

print("The min. and max. values of log(L) and log(N):",(min(x), max(x), min(y), max(y)))
print("\n")
p = max(y)
l = (max(x) - min(x))
n = (max(y) - min(y))
m = (p/l)
print("The Slope of log(L) versus log(N):", m)
print("\n")
# Out:
# The min. and max. values of log(L) and log(N): (0.0, 4.605170185988092, -inf, 1.9164629225230747)
#
#
# The Slope of log(L) versus log(N): 0.4161546360119753

# %%
#@title
import numpy as np
import matplotlib.pyplot as plt
import random

numbere = 1
num_a = 1000
e = []
for j in range(numbere):
  ax = plt.axes(projection="3d")
  a = np.random.uniform(size=num_a)
  b = np.random.uniform(size=num_a)
  c = np.random.uniform(size=num_a)
  a = c
  ex = [0]
  ey = [0]
  ez = [0]
  for i in range(len(a)):
    Lambda = -np.log(a[i])
    phi = 2*np.pi*b[i]
    theta = 2*np.arcsin(c[i])

    X = (Lambda*np.sin(theta)*np.cos(phi)) 
    Y = (Lambda*np.sin(theta)*np.sin(phi)) 
    Z = (Lambda*np.cos(theta)) 

    ex.append(X)
    ey.append(Y)
    ez.append(Z)
  plt.plot(ex, ey, ez, linestyle='-',color ="navy", linewidth = 3, marker='o', markerfacecolor='green', markersize=10)
plt.show()

L = []
lx = 0
ly = 0
lz = 0
N = []
n = 1
for i in range(len(a)):
  N.append(n)
  n = n + 1
  lx = lx + (ex[i])
  ly = ly + (ey[i])
  lz = lz + (ez[i])
  L.append(((lx+ly+lz)**(1/2)))

plt.plot(N, L, color ="darkblue")
plt.title("The Distance from the Source against Number of Collisions: Absolute Values")
plt.xlabel("Number of Collisions")
plt.ylabel("The Distance from the Source")
plt.show()

# %%
#@title
import numpy as np
from scipy import stats
import numpy
import pandas as pd

numpy.seterr(divide = 'ignore')
y = np.log(L)
x = np.log(N)
plt.plot(x,y, c = "navy")
plt.title("The graph of log(L) versus log(N)", fontsize = "20")
plt.xlabel("log(N)", fontsize = "20")
plt.ylabel("log(L)", fontsize = "20")
plt.grid()

print("The min. and max. values of log(L) and log(N):",(min(x), max(x), min(y), max(y)))
print("\n")
p = max(y)
l = (max(x) - min(x))
n = (max(y) - min(y))
m = (p/l)
print("The Slope of log(L) versus log(N):", m)
print("\n")
# Out:
# The min. and max. values of log(L) and log(N): (0.0, 6.907755278982137, -inf, 3.298970399646576)
#
#
# The Slope of log(L) versus log(N): 0.47757488017622446

# %%
#@title
import numpy as np
import matplotlib.pyplot as plt
import random

numbere = 1
num_a = 1000
e = []
for j in range(numbere):
  ax = plt.axes(projection="3d")
  a = np.random.uniform(size=num_a)
  b = np.random.uniform(size=num_a)
  c = np.random.uniform(size=num_a)
  a = c
  ex = [0]
  ey = [0]
  ez = [0]
  for i in range(len(a)):
    Lambda = -np.log(a[i])
    phi = 2*np.pi*b[i]
    theta = 2*np.arcsin(c[i])

    X = (Lambda*np.sin(theta)*np.cos(phi)) 
    Y = (Lambda*np.sin(theta)*np.sin(phi)) 
    Z = (Lambda*np.sin(theta)) 

    ex.append(X)
    ey.append(Y)
    ez.append(Z)
  plt.plot(ex, ey, ez, linestyle='-',color ="navy", linewidth = 3, marker='o', markerfacecolor='green', markersize=10)
plt.show()

L = []
lx = 0
ly = 0
lz = 0
N = []
n = 1
for i in range(len(a)):
  N.append(n)
  n = n + 1
  lx = lx + (ex[i])
  ly = ly + (ey[i])
  lz = lz + (ez[i])
  L.append(((lx+ly+lz)**(1/2)))

plt.plot(N, L, color ="darkblue")
plt.title("The Distance from the Source against Number of Collisions: Absolute Values")
plt.xlabel("Number of Collisions")
plt.ylabel("The Distance from the Source")
plt.show()

# %%
#@title
import numpy as np
import matplotlib.pyplot as plt
import random

numbere = 1
num_a = 10000
e = []
for j in range(numbere):
  ax = plt.axes(projection="3d")
  a = np.random.uniform(size=num_a)
  b = np.random.uniform(size=num_a)
  c = np.random.uniform(size=num_a)
  a = c
  ex = [0]
  ey = [0]
  ez = [0]
  for i in range(len(a)):
    Lambda = -np.log(a[i])
    phi = 2*np.pi*b[i]
    theta = 2*np.arcsin(c[i])

    X = (Lambda*np.sin(theta)*np.cos(phi)) 
    Y = (Lambda*np.sin(theta)*np.sin(phi)) 
    Z = (Lambda*np.cos(theta)) 

    ex.append(X)
    ey.append(Y)
    ez.append(Z)
  plt.plot(ex, ey, ez, linestyle='-',color ="navy", linewidth = 3, marker='o', markerfacecolor='green', markersize=10)
plt.show()

L = []
lx = 0
ly = 0
lz = 0
N = []
n = 1
for i in range(len(a)):
  N.append(n)
  n = n + 1
  lx = lx + (ex[i])
  ly = ly + (ey[i])
  lz = lz + (ez[i])
  L.append(((lx+ly+lz)**(1/2)))

plt.plot(N, L, color ="darkblue")
plt.title("The Distance from the Source against Number of Collisions: Absolute Values")
plt.xlabel("Number of Collisions")
plt.ylabel("The Distance from the Source")
plt.show()

# %%
#@title
import numpy as np
from scipy import stats
import numpy
import pandas as pd

numpy.seterr(divide = 'ignore')
y = np.log(L)
x = np.log(N)
plt.plot(x,y, c = "navy")
plt.title("The graph of log(L) versus log(N)", fontsize = "20")
plt.xlabel("log(N)", fontsize = "20")
plt.ylabel("log(L)", fontsize = "20")
plt.grid()

print("The min. and max. values of log(L) and log(N):",(min(x), max(x), min(y), max(y)))
print("\n")
p = max(y)
l = (max(x) - min(x))
n = (max(y) - min(y))
m = (p/l)
print("The Slope of log(L) versus log(N):", m)
print("\n")
# Out:
# The min. and max. values of log(L) and log(N): (0.0, 9.210340371976184, -inf, 4.49228871510718)
#
#
# The Slope of log(L) versus log(N): 0.48774405002182436

# %%
#@title
import numpy as np
import matplotlib.pyplot as plt
import random

numbere = 1
num_a = 10000
e = []
for j in range(numbere):
  ax = plt.axes(projection="3d")
  a = np.random.uniform(size=num_a)
  b = np.random.uniform(size=num_a)
  c = np.random.uniform(size=num_a)
  a = c
  ex = [0]
  ey = [0]
  ez = [0]
  for i in range(len(a)):
    Lambda = -np.log(a[i])
    phi = 2*np.pi*b[i]
    theta = 2*np.arcsin(c[i])

    X = (Lambda*np.sin(theta)*np.cos(phi)) 
    Y = (Lambda*np.sin(theta)*np.sin(phi)) 
    Z = (Lambda*np.sin(theta)) 

    ex.append(X)
    ey.append(Y)
    ez.append(Z)
  plt.plot(ex, ey, ez, linestyle='-',color ="navy", linewidth = 3, marker='o', markerfacecolor='green', markersize=10)
plt.show()

L = []
lx = 0
ly = 0
lz = 0
N = []
n = 1
for i in range(len(a)):
  N.append(n)
  n = n + 1
  lx = lx + (ex[i])
  ly = ly + (ey[i])
  lz = lz + (ez[i])
  L.append(((lx+ly+lz)**(1/2)))

plt.plot(N, L, color ="darkblue")
plt.title("The Distance from the Source against Number of Collisions: Absolute Values")
plt.xlabel("Number of Collisions")
plt.ylabel("The Distance from the Source")
plt.show()
